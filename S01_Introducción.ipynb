# %% [markdown]
# <a href="https://colab.research.google.com/github/jubaal91/Geoestadistica/blob/main/S01_Introducci%C3%B3n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Acceder a directorio especificado

import os
ruta_carpeta = '/content/drive/MyDrive/SciData/GEOAES_25/Mapas/Mexico_ent/'

# %%
#Cargar el mapa

import geopandas as gpd

Mapa = gpd.read_file(ruta_carpeta + '00ent.shp')

# %%
Mapa.head(5)
# Out:
#   CVEGEO CVE_ENT                NOMGEO  \
# 0     01      01        Aguascalientes
# 1     02      02       Baja California
# 2     03      03   Baja California Sur
# 3     04      04              Campeche
# 4     05      05  Coahuila de Zaragoza
#
#                                             geometry
# 0  POLYGON ((2469550.852 1159302.643, 2469738.209...
# 1  MULTIPOLYGON (((1313480.513 1831458.607, 13135...
# 2  MULTIPOLYGON (((1694656.345 1227647.637, 16946...
# 3  MULTIPOLYGON (((3544897.199 946994.621, 354491...
# 4  POLYGON ((2469501.165 1978862.429, 2469539.651...
